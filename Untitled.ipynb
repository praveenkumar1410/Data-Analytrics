# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
print("imported")
# Out:
# imported

# %% [markdown]
# # Pandas functions to read_csv and simple operations

# %%
path = "CarPrice_Assignment.csv"
df = pd.read_csv(path)

# %%
df.describe(include = 'all')
# Out:
#             car_ID   symboling        CarName fueltype aspiration doornumber
# count   205.000000  205.000000            205      205        205        205  \
# unique         NaN         NaN            147        2          2          2
# top            NaN         NaN  toyota corona      gas        std       four
# freq           NaN         NaN              6      185        168        115
# mean    103.000000    0.834146            NaN      NaN        NaN        NaN
# std      59.322565    1.245307            NaN      NaN        NaN        NaN
# min       1.000000   -2.000000            NaN      NaN        NaN        NaN
# 25%      52.000000    0.000000            NaN      NaN        NaN        NaN
# 50%     103.000000    1.000000            NaN      NaN        NaN        NaN
# 75%     154.000000    2.000000            NaN      NaN        NaN        NaN
# max     205.000000    3.000000            NaN      NaN        NaN        NaN
#
# ...

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber
# 0       1          3        alfa-romero giulia      gas        std        two  \
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize
# 0  convertible        rwd          front       88.6  ...         130  \
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg
# ...

# %%
df.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
df.dtypes
# Out:
# car_ID                int64
# symboling             int64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %% [markdown]
# >

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Missing values
#
# ## Data Formatting
#
# ## Data Normalization
#
# ## Data Binning
#
# ## Training categorical values to numerical valuse

# %% [markdown]
# >

# %% [markdown]
# # # 1. Drop missing values

# %%
df.dropna(axis=0) #for dropping entire row axis = 0
# Out:
#      car_ID  symboling                   CarName fueltype aspiration
# 0         1          3        alfa-romero giulia      gas        std  \
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...
# ...

# %%
df.dropna(axis = 1) # for dropping column having nan
# Out:
#      car_ID  symboling                   CarName fueltype aspiration
# 0         1          3        alfa-romero giulia      gas        std  \
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...
# ...

# %%
df.dropna(subset=["price"],axis=0) # specifying a certain attr to drop NaN values
# Out:
#      car_ID  symboling                   CarName fueltype aspiration
# 0         1          3        alfa-romero giulia      gas        std  \
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...
# ...

# %% [markdown]
# ## 2.Replacing missing values

# %% [markdown]
# ### By avg

# %%
df.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
df1 = pd.read_csv("IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork_labs_jupyterlite_files_auto.csv")

# %%
df1.columns
# Out:
# Index(['3', '?', 'alfa-romero', 'gas', 'std', 'two', 'convertible', 'rwd',
#        'front', '88.6', '168.8', '64.1', '48.8', '2548', 'dohc', 'four', '130',
#        'mpfi', '3.47', '2.68', '9.0', '111', '5000', '21', '27', '13495'],
#       dtype='object')

# %%
header = ['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
       'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
       'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
       'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
       'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
       'highway-mpg', 'price']
df1.columns = header

# %%
df1.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
df1.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors
# 0          3                 ?  alfa-romero       gas        std          two  \
# 1          1                 ?  alfa-romero       gas        std          two
# 2          2               164         audi       gas        std         four
# 3          2               164         audi       gas        std         four
# 4          2                 ?         audi       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size
# 0  convertible          rwd           front        88.6  ...          130  \
# 1    hatchback          rwd           front        94.5  ...          152
# 2        sedan          fwd           front        99.8  ...          109
# 3        sedan          4wd           front        99.4  ...          136
# 4        sedan          fwd           front        99.8  ...          136
#
# ...

# %%
df1.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
df1.replace("?", np.nan, inplace = True)
df1.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors
# 0          3               NaN  alfa-romero       gas        std          two  \
# 1          1               NaN  alfa-romero       gas        std          two
# 2          2               164         audi       gas        std         four
# 3          2               164         audi       gas        std         four
# 4          2               NaN         audi       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size
# 0  convertible          rwd           front        88.6  ...          130  \
# 1    hatchback          rwd           front        94.5  ...          152
# 2        sedan          fwd           front        99.8  ...          109
# 3        sedan          4wd           front        99.4  ...          136
# 4        sedan          fwd           front        99.8  ...          136
#
# ...

# %%
df1["normalized-losses"] = df1["normalized-losses"].astype("float")

# %%
mean = df1["normalized-losses"].mean()

# %%
df1["normalized-losses"].replace(np.nan,mean, inplace = True)

# %%
df1.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration
# 0          3              122.0  alfa-romero       gas        std  \
# 1          1              122.0  alfa-romero       gas        std
# 2          2              164.0         audi       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              122.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...
# 0          two  convertible          rwd           front        88.6  ...  \
# 1          two    hatchback          rwd           front        94.5  ...
# 2         four        sedan          fwd           front        99.8  ...
# 3         four        sedan          4wd           front        99.4  ...
# 4          two        sedan          fwd           front        99.8  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower
# ...

# %% [markdown]
# ## Data Formatting

# %% [markdown]
# + conversion of one unit to another common unit eg : mpg to Lpkm

# %%
df1["city-mpg"] = 235/ df1["city-mpg"]

# %%
df1.rename(columns={"city-mpg":"city-l/100km"},inplace=True)
df1.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration
# 0          3              122.0  alfa-romero       gas        std  \
# 1          1              122.0  alfa-romero       gas        std
# 2          2              164.0         audi       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              122.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...
# 0          two  convertible          rwd           front        88.6  ...  \
# 1          two    hatchback          rwd           front        94.5  ...
# 2         four        sedan          fwd           front        99.8  ...
# 3         four        sedan          4wd           front        99.4  ...
# 4          two        sedan          fwd           front        99.8  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower
# ...

# %% [markdown]
# ## Data Normalization
# + Note : Use any one method for all attr in the table u wanted to normalize

# %% [markdown]
# ### 1.Simple Feature Scaling
#
# + Xnew = Xold/Xmax

# %%
#normalization of Length
df1["length"]= df1["length"] / df1["length"].max()
df1["length"].head()
# Out:
# 0    0.811148
# 1    0.822681
# 2    0.848630
# 3    0.848630
# 4    0.851994
# Name: length, dtype: float64

# %% [markdown]
# ### 2.Min-Max
# + Xnew = (Xold - Xmin) / (Xmax - Xmin)

# %% [markdown]
# df1["height"] = df1["height"] - df1["height"].max() / df1["height"].max() - df1["height"].min()
# df1["height"].head()

# %% [markdown]
# ### 3.Z-Score
# + Xnew = xold - mean / SD

# %%
df1["width"] = df1["width"] - df1["width"].mean() /df1["width"].std()
df1["width"].head()
# Out:
# 0    33.394188
# 1    34.794188
# 2    35.494188
# 3    35.694188
# 4    35.594188
# Name: width, dtype: float64

# %% [markdown]
# ## Data Binning
#
# + Grouping a attribute to categories
# + Bins are created by equal intervals from min value to max value

# %%
df1[["bore", "stroke"]] = df1[["bore", "stroke"]].astype("float")
df1[["normalized-losses"]] = df1[["normalized-losses"]].astype("int")
df1[["price"]] = df1[["price"]].astype("float")
df1[["peak-rpm"]] = df1[["peak-rpm"]].astype("float")

df1["price"].dropna(axis=0,inplace = True)
# Creating bins
bins = np.linspace(min(df1["price"]),max(df1["price"]),4)

# %%
#creating grps
grp_name = ["low","medium","high"]
df1["price_binned"] = pd.cut(df1["price"],bins,labels=grp_name,include_lowest = True)
df1.head(10)
# Out:
#    symboling  normalized-losses         make fuel-type aspiration
# 0          3                122  alfa-romero       gas        std  \
# 1          1                122  alfa-romero       gas        std
# 2          2                164         audi       gas        std
# 3          2                164         audi       gas        std
# 4          2                122         audi       gas        std
# 5          1                158         audi       gas        std
# 6          1                122         audi       gas        std
# 7          1                158         audi       gas      turbo
# 8          0                122         audi       gas      turbo
# 9          2                192          bmw       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...
# 0          two  convertible          rwd           front        88.6  ...  \
# 1          two    hatchback          rwd           front        94.5  ...
# ...

# %%
df1.dtypes
# Out:
# symboling               int64
# normalized-losses       int32
# make                   object
# fuel-type              object
# aspiration             object
# num-of-doors           object
# body-style             object
# drive-wheels           object
# engine-location        object
# wheel-base            float64
# length                float64
# width                 float64
# height                float64
# curb-weight             int64
# engine-type            object
# num-of-cylinders       object
# engine-size             int64
# fuel-system            object
# bore                  float64
# stroke                float64
# compression-ratio     float64
# horsepower             object
# peak-rpm              float64
# city-l/100km          float64
# highway-mpg             int64
# price                 float64
# price_binned         category
# dtype: object

# %% [markdown]
# ### Turning categorical values into quantitative variables

# %%
# Dummy variables

pd.get_dummies(df1['fuel-type'])
# Out:
#      diesel    gas
# 0     False   True
# 1     False   True
# 2     False   True
# 3     False   True
# 4     False   True
# ..      ...    ...
# 199   False   True
# 200   False   True
# 201   False   True
# 202    True  False
# 203   False   True
#
# [204 rows x 2 columns]

# %% [markdown]
# ## Exploratory Data analysis ( EDA )
#
# > descriptive statistics,
# > Groupby,
# > ANOVA,
# > Correlation,
# > Correlation-Sattistics

# %%
drive_wheel_count = df1["drive-wheels"].value_counts()
drive_wheel_count
# Out:
# drive-wheels
# fwd    120
# rwd     75
# 4wd      9
# Name: count, dtype: int64

# %%
sns.boxplot(x='drive-wheels',y='price',data = df1)
# Out:
# <Axes: xlabel='drive-wheels', ylabel='price'>

# %% [markdown]
# ### Scatter Plot

# %%
x= df1["engine-size"]
y=df1["price"]
plt.scatter(x,y)

# %% [markdown]
# ### Group by

# %%
test = df1[["drive-wheels","body-style","price"]]
grp = test.groupby(["drive-wheels","body-style"],as_index = False).mean()
grp
# Out:
#    drive-wheels   body-style         price
# 0           4wd    hatchback   7603.000000
# 1           4wd        sedan  12647.333333
# 2           4wd        wagon   9095.750000
# 3           fwd  convertible  11595.000000
# 4           fwd      hardtop   8249.000000
# 5           fwd    hatchback   8396.387755
# 6           fwd        sedan   9811.800000
# 7           fwd        wagon   9997.333333
# 8           rwd  convertible  26563.250000
# 9           rwd      hardtop  24202.714286
# 10          rwd    hatchback  14337.777778
# 11          rwd        sedan  21711.833333
# 12          rwd        wagon  16994.222222

# %%
#pivot() method

df1_pivot = grp.pivot(index = 'drive-wheels',columns='body-style')
df1_pivot
# Out:
#                    price
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  NaN           NaN   7603.000000  12647.333333  \
# fwd             11595.00   8249.000000   8396.387755   9811.800000
# rwd             26563.25  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
import matplotlib.pyplot as plt

plt.pcolor(df1_pivot,cmap = "RdBu")
plt.colorbar()
plt.show()

# %% [markdown]
# ### Correlation coefficient

# %%
from scipy import stats

# %% [markdown]
# # Model Development

# %%
from sklearn.linear_model import LinearRegression
df1["price"].dropna()
# Out:
# 0      16500.0
# 1      16500.0
# 2      13950.0
# 3      17450.0
# 4      15250.0
#         ...
# 199    16845.0
# 200    19045.0
# 201    21485.0
# 202    22470.0
# 203    22625.0
# Name: price, Length: 200, dtype: float64

# %%
lm = LinearRegression() # linear regression object
lm
# Out:
# LinearRegression()

# %%
df.dtypes
# Out:
# car_ID                int64
# symboling             int64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %%
df1.describe(include="all")
# Out:
#          symboling  normalized-losses    make fuel-type aspiration
# count   204.000000         204.000000     204       204        204  \
# unique         NaN                NaN      22         2          2
# top            NaN                NaN  toyota       gas        std
# freq           NaN                NaN      32       184        167
# mean      0.823529         122.000000     NaN       NaN        NaN
# std       1.239035          31.758944     NaN       NaN        NaN
# min      -2.000000          65.000000     NaN       NaN        NaN
# 25%       0.000000         101.000000     NaN       NaN        NaN
# 50%       1.000000         122.000000     NaN       NaN        NaN
# 75%       2.000000         137.000000     NaN       NaN        NaN
# max       3.000000         256.000000     NaN       NaN        NaN
#
#        num-of-doors body-style drive-wheels engine-location  wheel-base  ...
# count           202        204          204             204  204.000000  ...  \
# ...

# %%
x = df[['enginesize']]
y = df['price']
lm.fit(x,y)
# Out:
# LinearRegression()

# %%
model = lm.predict(x)
model
# Out:
# array([13795.34859997, 13795.34859997, 17484.71376062, 10273.68185571,
#        14801.53909833, 14801.53909833, 14801.53909833, 14801.53909833,
#        13963.04701636, 13963.04701636, 10105.98343932, 10105.98343932,
#        19497.09475734, 19497.09475734, 19497.09475734, 27043.52349503,
#        27043.52349503, 27043.52349503,  2224.15786884,  7087.41194424,
#         7087.41194424,  7087.41194424,  7087.41194424,  8428.99927539,
#         7087.41194424,  7087.41194424,  7087.41194424,  8428.99927539,
#        12453.76126882, 18155.50742619,  7422.80877703,  7422.80877703,
#         5242.72936392,  7422.80877703,  7422.80877703,  7422.80877703,
#         7422.80877703, 10441.3802721 , 10441.3802721 , 10441.3802721 ,
#        10441.3802721 , 10441.3802721 , 10441.3802721 , 10609.0786885 ,
#         7087.41194424,  7087.41194424, 11950.66601964, 35260.74589829,
#        35260.74589829, 46664.23821303,  7255.11036063,  7255.11036063,
# ...

# %%
lm.intercept_
# Out:
# -8005.445531145215

# %%
lm.coef_
# Out:
# array([167.69841639])

# %%
#equation 

#x = intercept + (slope)y

price = -8005.445531145215 + 167.69841639 * y

# %% [markdown]
# # Multiple Linear Regression

# %%
z = df[['horsepower', 'curbweight', 'enginesize', 'highwaympg']]

# %%
lm.fit(z,df['price'])
# Out:
# LinearRegression()

# %%
y_hat=lm.predict(z)
y_hat
# Out:
# array([13705.65874827, 13705.65874827, 19012.54779171, 10642.39806986,
#        15485.97998725, 13878.04669385, 15438.4915069 , 15947.83551115,
#        17515.45953502, 18493.00642633, 10735.11919185, 10735.11919185,
#        17832.21534741, 18086.88734954, 19307.56818189, 26915.76024991,
#        27610.32025572, 28107.69680797,   846.62315969,  5778.49625251,
#         5940.56025386,  5601.440936  ,  5479.30575713,  8765.12022023,
#         5900.67216066,  6002.54096151,  6002.54096151,  9056.83542267,
#        11899.86091497, 18734.27863849,  5016.84289539,  5800.31165484,
#         4132.47216325,  6197.74315437,  6271.82955498,  6521.87115707,
#         6586.69675762,  9540.40555478,  9785.81675683,  9855.27275741,
#        10170.13996004, 11183.90351219, 10457.1635524 ,  9508.34241948,
#         5778.49625251,  5940.56025386, 12637.43939451, 34401.47858734,
#        34401.47858734, 43915.82677543,  5341.8332956 ,  5673.11938002,
# ...

# %%
lm.coef_
# Out:
# array([52.446332  ,  4.63040004, 82.68402196, 40.71172629])

# %%
lm.intercept_
# Out:
# -15762.282866748166

# %% [markdown]
# <h2>2. Model Evaluation Using Visualization</h2>

# %%
import seaborn as sns
# %matplotlib inline

# %%
width =10
height =12
plt.figure(figsize=(width, height))
sns.regplot(x="highwaympg", y="price", data=df)
plt.ylim(0,)
# Out:
# (0.0, 48140.190482085876)

# %%
sns.regplot(x="enginesize",y="price",data = df)
# Out:
# <Axes: xlabel='enginesize', ylabel='price'>

# %%
sns.residplot(x=df['highwaympg'],y=df['price'])
plt.show()

# %% [markdown]
# <h3>Multiple Linear Regression</h3>

# %%
ax1 = sns.distplot(df['price'], hist=False, color="r", label="Actual Value")
sns.distplot(y_hat, hist=False, color="b", label="Fitted Values" , ax=ax1)


plt.title('Actual vs Fitted Values for Price')
plt.xlabel('Price (in dollars)')
plt.ylabel('Proportion of Cars')

plt.show()
plt.close()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13820\1384982332.py:1: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# C:\Users\HP\AppData\Local\Temp\ipykernel_13820\1384982332.py:2: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %% [markdown]
# <h2>3. Polynomial Regression and Pipelines</h2>

# %%
x = df['highwaympg']
y = df['price']

# %%
f = np.polyfit(x, y, 3)
p = np.poly1d(f)
print(p)
# Out:
#         3         2
# -1.496 x + 197.9 x - 8714 x + 1.351e+05

# %%
np.polyfit(x, y, 3)
# Out:
# array([-1.49603403e+00,  1.97860523e+02, -8.71437435e+03,  1.35089693e+05])

# %%
def PlotPolly(model, independent_variable, dependent_variabble, Name):
    x_new = np.linspace(15, 55, 100)
    y_new = model(x_new)

    plt.plot(independent_variable, dependent_variabble, '.', x_new, y_new, '-')
    plt.title('Polynomial Fit with Matplotlib for Price ~ Length')
    ax = plt.gca()
    ax.set_facecolor((0.898, 0.898, 0.898))
    fig = plt.gcf()
    plt.xlabel(Name)
    plt.ylabel('Price of Cars')

    plt.show()
    plt.close()

# %%
PlotPolly(p, x, y, 'highwaympg')

# %%
f1 = np.polyfit(x,y,11)

# %%
p1 =np.poly1d(f1)
p1
# Out:
# poly1d([-1.32768163e-08,  5.04626212e-06, -8.58317106e-04,  8.61727446e-02,
#        -5.66964685e+00,  2.56482309e+02, -8.13426844e+03,  1.80729798e+05,
#        -2.75513772e+06,  2.74316285e+07, -1.60496039e+08,  4.18051025e+08])

# %%
PlotPolly(p1,x,y,'highwaympg')

# %% [markdown]
# ### Polynomial features

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pr = PolynomialFeatures()
pr
# Out:
# PolynomialFeatures()

# %%
pr.fit(z,y)
# Out:
# PolynomialFeatures()

# %%
pr_z = pr.fit_transform(z)

# %%
z.shape
# Out:
# (205, 4)

# %%
pr_z.shape
# Out:
# (205, 15)

# %% [markdown]
# ## Pipeline

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
Input = [('scale',StandardScaler()),('polynimials',PolynomialFeatures()),('models',LinearRegression())]

# %%
pipe = Pipeline(Input)

# %%
z=z.astype(float)

# %%
pipe.fit(z,y)
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('polynimials', PolynomialFeatures()),
#                 ('models', LinearRegression())])

# %%
ypipe = pipe.predict(z)
ypipe
# Out:
# array([13216.64047596, 13216.64047596, 18254.13517304, 10557.21336422,
#        16047.08642103, 13811.35443866, 15007.20297902, 15452.41512279,
#        18312.26227632, 18896.77503091, 10623.67876759, 10623.67876759,
#        15989.1814734 , 16179.03049074, 18531.55382226, 25486.67036722,
#        25168.26252878, 26637.79512095,  6205.61220958,  6531.91122199,
#         6532.56089677,  6296.91121852,  6036.52984367, 10388.03816422,
#         6227.41536016,  6276.33798943,  6276.33798943, 10281.94935109,
#        11113.91876358, 18707.43583284,  7360.56354979,  6783.21295117,
#         5480.67832746,  6672.84244321,  6701.88761334,  6804.13370436,
#         6831.70442293,  8851.63191835,  8990.16667883,  9030.51299357,
#         9219.71523269, 10989.58889209, 10232.92988675,  9071.57458762,
#         6531.91122199,  6532.56089677, 12011.49032547, 36274.13340908,
#        36274.13340908, 41558.89421302,  5263.46201467,  6119.24734373,
# ...

# %% [markdown]
# ## In-sample Evaluation
#
# ### R-Square r2
#
# ### Mean Square Error

# %%
x = df[['highwaympg']]
y = df['price']
lm.fit(x,y)
# Out:
# LinearRegression()

# %%
print("R-Square value: ",lm.score(x,y))
# Out:
# R-Square value:  0.48664449266610066

# %%
yhat=lm.predict(x)
yhat[0:5]
# Out:
# array([16312.47322074, 16312.47322074, 17121.74674903, 13884.65263588,
#        20358.84086218])

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(df['price'],yhat)
mse
# Out:
# 32603432.048684955

# %% [markdown]
# # Model evaluation and Improvement

# %%
path = 'module_5_auto.csv'
df = pd.read_csv(path)

# %%
df.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0  Unnamed: 0.1  symboling  normalized-losses
# 0             0           0             0          3                122  \
# 1             1           1             1          3                122
# 2             2           2             2          1                122
# 3             3           3             3          2                164
# 4             4           4             4          2                164
#
#           make aspiration num-of-doors   body-style drive-wheels  ...
# 0  alfa-romero        std          two  convertible          rwd  ...  \
# 1  alfa-romero        std          two  convertible          rwd  ...
# 2  alfa-romero        std          two    hatchback          rwd  ...
# 3         audi        std         four        sedan          fwd  ...
# 4         audi        std         four        sedan          4wd  ...
#
#   compression-ratio  horsepower  peak-rpm  city-mpg  highway-mpg    price
# ...

# %%
df=df._get_numeric_data()

# %%
df.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0  Unnamed: 0.1  symboling  normalized-losses
# 0             0           0             0          3                122  \
# 1             1           1             1          3                122
# 2             2           2             2          1                122
# 3             3           3             3          2                164
# 4             4           4             4          2                164
#
#    wheel-base    length     width  height  curb-weight  ...  stroke
# 0        88.6  0.811148  0.890278    48.8         2548  ...    2.68  \
# 1        88.6  0.811148  0.890278    48.8         2548  ...    2.68
# 2        94.5  0.822681  0.909722    52.4         2823  ...    3.47
# 3        99.8  0.848630  0.919444    54.3         2337  ...    3.40
# 4        99.4  0.848630  0.922222    54.3         2824  ...    3.40
#
#    compression-ratio  horsepower  peak-rpm  city-mpg  highway-mpg    price
# ...

# %%
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
    width = 12
    height = 10
    plt.figure(figsize=(width, height))

    ax1 = sns.distplot(RedFunction, hist=False, color="r", label=RedName)
    ax2 = sns.distplot(BlueFunction, hist=False, color="b", label=BlueName, ax=ax1)

    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of Cars')

    plt.show()
    plt.close()

# %%
def PollyPlot(xtrain, xtest, y_train, y_test, lr,poly_transform):
    width = 12
    height = 10
    plt.figure(figsize=(width, height))
    
    
    #training data 
    #testing data 
    # lr:  linear regression object 
    #poly_transform:  polynomial transformation object 
 
    xmax=max([xtrain.values.max(), xtest.values.max()])

    xmin=min([xtrain.values.min(), xtest.values.min()])

    x=np.arange(xmin, xmax, 0.1)


    plt.plot(xtrain, y_train, 'ro', label='Training Data')
    plt.plot(xtest, y_test, 'go', label='Test Data')
    plt.plot(x, lr.predict(poly_transform.fit_transform(x.reshape(-1, 1))), label='Predicted Function')
    plt.ylim([-10000, 60000])
    plt.ylabel('Price')
    plt.legend()

# %% [markdown]
# <h2 id="ref1">Part 1: Training and Testing</h2>

# %%
y_data = df['price']
x_data=df.drop('price',axis=1)

# %%
from sklearn.model_selection import train_test_split


x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.30, random_state=1)


print("number of test samples :", x_test.shape[0])
print("number of training samples:",x_train.shape[0])
# Out:
# number of test samples : 61
# number of training samples: 140

# %%
lm.fit(x_train[['horsepower']],y_train)
# Out:
# LinearRegression()

# %%
lm.score(x_test[['horsepower']], y_test)
# Out:
# 0.6287485044222195

# %%
lm.score(x_train[['horsepower']], y_train)
# Out:
# 0.6628063120233265

# %% [markdown]
# ### Cross Val Score

# %%
from sklearn.model_selection import cross_val_score

# %%
Rcross = cross_val_score(lm, x_data[['horsepower']], y_data, cv=4)
Rcross
# Out:
# array([0.7746232 , 0.51716687, 0.74785353, 0.04839605])

# %%
Rcross.mean()
# Out:
# 0.522009915042119

# %%
Rcross.std()
# Out:
# 0.2911839444756029

# %% [markdown]
# ### Cross Val Prediction

# %%
from sklearn.model_selection import cross_val_predict

# %%
yhat = cross_val_predict(lm,x_data[['horsepower']], y_data,cv=4)
yhat[0:4]
# Out:
# array([14141.63807508, 14141.63807508, 20814.29423473, 12745.03562306])

# %% [markdown]
# <h2 id="ref2">Part 2: Overfitting, Underfitting and Model Selection</h2>

# %%
lm.fit(x_train[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']], y_train)
# Out:
# LinearRegression()

# %%
yhat_train = lm.predict(x_train[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']])
yhat_train[0:5]
# Out:
# array([29846.60235605,  6884.07996697,  6770.88556096,  9674.82900088,
#          589.60207942])

# %%
yhat_test = lm.predict(x_test[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']])
yhat_test[0:5]
# Out:
# array([11464.00435188,  5969.22232769, 11274.27750732,  6781.39943371,
#        15787.13024319])

# %%
Title = 'Distribution  Plot of  Predicted Value Using Training Data vs Training Data Distribution'
DistributionPlot(y_train, yhat_train, "Actual Values (Train)", "Predicted Values (Train)", Title)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13820\483544288.py:6: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# C:\Users\HP\AppData\Local\Temp\ipykernel_13820\483544288.py:7: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %%
Title='Distribution  Plot of  Predicted Value Using Test Data vs Data Distribution of Test Data'
DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",Title)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13820\483544288.py:6: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# C:\Users\HP\AppData\Local\Temp\ipykernel_13820\483544288.py:7: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %%
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.45, random_state=1)

# %%
pr = PolynomialFeatures(degree=5)

# %%
x_train_pr = pr.fit_transform(x_train[['horsepower']])
x_test_pr = pr.fit_transform(x_test[['horsepower']])

# %%
poly = LinearRegression()

# %%
poly.fit(x_train_pr,y_train)
# Out:
# LinearRegression()

# %%
yhat=poly.predict(x_test_pr)

# %%
yhat
# Out:
# array([11600.65921307,  7487.77266667,  9627.32780183,  8470.03572864,
#        14359.24682388,  6967.52467854, 18912.08768725, 10233.19983698,
#        14217.48771131,  7708.51434841, 10843.09683231,  8470.03572864,
#        14359.24682388, 15070.05898008, 13649.01954776, 11600.65921307,
#         6775.19805676, 12930.36376147,  7595.66155761,  9777.93071349,
#         9929.21443368,  7708.51434841, 28912.7129074 , 11298.83073436,
#         6853.27691659, 26846.16683861, 14359.24682388,  7487.77266667,
#        10843.09683231,  7595.66155761, 14075.66066628, 10233.19983698,
#        12197.77565922,  7595.66155761, 22444.45371387, 22190.55934626,
#        14359.24682388,  9328.85867067, 20325.42591485, 15357.11362718,
#         7487.77266667, 11298.83073436, 18540.58686735,  9627.32780183,
#        28912.7129074 ,  9627.32780183,  7708.51434841,  7487.77266667,
#         9929.21443368, 22190.55934626, 12676.60360998, 22703.17106804,
# ...

# %%
print("Predicted values:", yhat[0:4])
print("True values:", y_test[0:4].values)
# Out:
# Predicted values: [11600.65921307  7487.77266667  9627.32780183  8470.03572864]
# True values: [ 9549.  6229. 10245.  7295.]

# %%
PollyPlot(x_train['horsepower'], x_test['horsepower'], y_train, y_test, poly,pr)
